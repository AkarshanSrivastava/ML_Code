# %%
import pandas as pd

# %%
df_raw_data_1=pd.read_csv("sample_dataset_1.csv",header=None)

# %%
df_raw_data_1.columns=["item","userid","rating"]

# %%
df_raw_data_1.shape
# Out:
# (7, 3)

# %%
df_raw_data_1.head()
# Out:
#    item  userid  rating
# 0  bulb      20     6.5
# 1  tube      20     5.0
# 2   fan      20     6.0
# 3  tube      21     6.0
# 4  bulb      21     7.0

# %%
df_raw_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
# item      7 non-null object
# userid    7 non-null int64
# rating    7 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 248.0+ bytes

# %%
df_raw_data_1.describe()
# Out:
#           userid    rating
# count   7.000000  7.000000
# mean   21.142857  6.285714
# std     1.345185  0.809174
# min    20.000000  5.000000
# 25%    20.000000  6.000000
# 50%    21.000000  6.000000
# 75%    22.000000  6.750000
# max    23.000000  7.500000

# %%
df_raw_data_1.nunique()
# Out:
# item      3
# userid    3
# rating    5
# dtype: int64

# %%
df_raw_data_1["userid"].value_counts()
# Out:
# 20    3
# 23    2
# 21    2
# Name: userid, dtype: int64

# %%
df_raw_data_1["rating"].value_counts()
# Out:
# 6.0    3
# 7.5    1
# 7.0    1
# 5.0    1
# 6.5    1
# Name: rating, dtype: int64

# %%
print(df_raw_data_1.index)
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
print(list(df_raw_data_1.index))
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
df_raw_data_1.values
# Out:
# array([['bulb', 20, 6.5],
#        ['tube', 20, 5.0],
#        ['fan', 20, 6.0],
#        ['tube', 21, 6.0],
#        ['bulb', 21, 7.0],
#        ['bulb', 23, 7.5],
#        ['fan', 23, 6.0]], dtype=object)

# %%
df_raw_data_1.T
# Out:
#            0     1    2     3     4     5    6
# item    bulb  tube  fan  tube  bulb  bulb  fan
# userid    20    20   20    21    21    23   23
# rating   6.5     5    6     6     7   7.5    6

# %%
df_raw_data_1.T.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Apply

# %%
data=pd.read_csv('demo1_historic.csv')
data.head()
# Out:
#    ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 0  S1   41           1             1               3             23
# 1  S2   37           0             0               0              5
# 2  S3   49           0             0               0             44
# 3  S4   24           0             0               0             40
# 4  S5   48           1             1               3             36
#
#    Drinks_Tea  Lectures_Missed  Average_Assignments_Score  Exam_Result
# 0           0                1                         41            1
# 1           1                8                         75            1
# 2           1                9                         52            1
# 3           1                1                         54            1
# 4           0                2                         32            1

# %%
data["Age_in_days"]=data.Age.apply(lambda x:x*365.25)

# %%
data.head(3)
# Out:
#    ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 0  S1   41           1             1               3             23
# 1  S2   37           0             0               0              5
# 2  S3   49           0             0               0             44
#
#    Drinks_Tea  Lectures_Missed  Average_Assignments_Score  Exam_Result  \
# 0           0                1                         41            1
# 1           1                8                         75            1
# 2           1                9                         52            1
#
#    Age_in_days
# 0     14975.25
# 1     13514.25
# 2     17897.25

# %%
data["Age_in_days"]=round(data.Age_in_days,1)

# %%
data.head()
# Out:
#    ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 0  S1   41           1             1               3             23
# 1  S2   37           0             0               0              5
# 2  S3   49           0             0               0             44
# 3  S4   24           0             0               0             40
# 4  S5   48           1             1               3             36
#
#    Drinks_Tea  Lectures_Missed  Average_Assignments_Score  Exam_Result  \
# 0           0                1                         41            1
# 1           1                8                         75            1
# 2           1                9                         52            1
# 3           1                1                         54            1
# 4           0                2                         32            1
#
#    Age_in_days
# 0      14975.2
# 1      13514.2
# 2      17897.2
# 3       8766.0
# 4      17532.0

# %%
data["Age_in_days"]=data["Age_in_days"].astype(int)

# %%
data.head()
# Out:
#    ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 0  S1   41           1             1               3             23
# 1  S2   37           0             0               0              5
# 2  S3   49           0             0               0             44
# 3  S4   24           0             0               0             40
# 4  S5   48           1             1               3             36
#
#    Drinks_Tea  Lectures_Missed  Average_Assignments_Score  Exam_Result  \
# 0           0                1                         41            1
# 1           1                8                         75            1
# 2           1                9                         52            1
# 3           1                1                         54            1
# 4           0                2                         32            1
#
#    Age_in_days
# 0        14975
# 1        13514
# 2        17897
# 3         8766
# 4        17532

# %%
data1=data

# %%
data1["hello"]=0

# %%
data.head(3)
# Out:
#    ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 0  S1   41           1             1               3             23
# 1  S2   37           0             0               0              5
# 2  S3   49           0             0               0             44
#
#    Drinks_Tea  Lectures_Missed  Average_Assignments_Score  Exam_Result  \
# 0           0                1                         41            1
# 1           1                8                         75            1
# 2           1                9                         52            1
#
#    Age_in_days  hello
# 0        14975      0
# 1        13514      0
# 2        17897      0

# %%
data2=data.copy()

# %%
data2["hi"]=0

# %%
data2.head(3)
# Out:
#    ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 0  S1   41           1             1               3             23
# 1  S2   37           0             0               0              5
# 2  S3   49           0             0               0             44
#
#    Drinks_Tea  Lectures_Missed  Average_Assignments_Score  Exam_Result  \
# 0           0                1                         41            1
# 1           1                8                         75            1
# 2           1                9                         52            1
#
#    Age_in_days  hello  hi
# 0        14975      0   0
# 1        13514      0   0
# 2        17897      0   0

# %%
data.head(3)
# Out:
#    ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 0  S1   41           1             1               3             23
# 1  S2   37           0             0               0              5
# 2  S3   49           0             0               0             44
#
#    Drinks_Tea  Lectures_Missed  Average_Assignments_Score  Exam_Result  \
# 0           0                1                         41            1
# 1           1                8                         75            1
# 2           1                9                         52            1
#
#    Age_in_days  hello
# 0        14975      0
# 1        13514      0
# 2        17897      0

# %%
data2.head()
# Out:
#    ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 0  S1   41           1             1               3             23
# 1  S2   37           0             0               0              5
# 2  S3   49           0             0               0             44
# 3  S4   24           0             0               0             40
# 4  S5   48           1             1               3             36
#
#    Drinks_Tea  Lectures_Missed  Average_Assignments_Score  Exam_Result  \
# 0           0                1                         41            1
# 1           1                8                         75            1
# 2           1                9                         52            1
# 3           1                1                         54            1
# 4           0                2                         32            1
#
#    Age_in_days  hello  hi
# 0        14975      0   0
# 1        13514      0   0
# 2        17897      0   0
# ...

# %%
data2.Exam_Result.replace(1,0,inplace=True)

# %%
data2.head()
# Out:
#    ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 0  S1   41           1             1               3             23
# 1  S2   37           0             0               0              5
# 2  S3   49           0             0               0             44
# 3  S4   24           0             0               0             40
# 4  S5   48           1             1               3             36
#
#    Drinks_Tea  Lectures_Missed  Average_Assignments_Score  Exam_Result  \
# 0           0                1                         41            0
# 1           1                8                         75            0
# 2           1                9                         52            0
# 3           1                1                         54            0
# 4           0                2                         32            0
#
#    Age_in_days  hello  hi
# 0        14975      0   0
# 1        13514      0   0
# 2        17897      0   0
# ...

# %% [markdown]
# # Adding a Row

# %%
data2.shape
# Out:
# (1000, 13)

# %%
data2.loc[1000]=["454",1,2,3,4,5,6,7,8,9,1,2,3]

# %%
data2.shape
# Out:
# (1001, 13)

# %%
data2['Exam_Result'].duplicated().head()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# Name: Exam_Result, dtype: bool

# %%
data2.drop_duplicates().head()
# Out:
#    ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 0  S1   41           1             1               3             23
# 1  S2   37           0             0               0              5
# 2  S3   49           0             0               0             44
# 3  S4   24           0             0               0             40
# 4  S5   48           1             1               3             36
#
#    Drinks_Tea  Lectures_Missed  Average_Assignments_Score  Exam_Result  \
# 0           0                1                         41            0
# 1           1                8                         75            0
# 2           1                9                         52            0
# 3           1                1                         54            0
# 4           0                2                         32            0
#
#    Age_in_days  hello  hi
# 0        14975      0   0
# 1        13514      0   0
# 2        17897      0   0
# ...

# %%
data2.loc[1002]=['S1',41,1,1,3,23,0,1,41,0,14975,0,0]

# %%
data2.shape
# Out:
# (1002, 13)

# %%
data2.drop_duplicates(keep='first',inplace=True)

# %%
data2.head()
# Out:
#    ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 0  S1   41           1             1               3             23
# 1  S2   37           0             0               0              5
# 2  S3   49           0             0               0             44
# 3  S4   24           0             0               0             40
# 4  S5   48           1             1               3             36
#
#    Drinks_Tea  Lectures_Missed  Average_Assignments_Score  Exam_Result  \
# 0           0                1                         41            0
# 1           1                8                         75            0
# 2           1                9                         52            0
# 3           1                1                         54            0
# 4           0                2                         32            0
#
#    Age_in_days  hello  hi
# 0        14975      0   0
# 1        13514      0   0
# 2        17897      0   0
# ...

# %%
data2.loc[1002]=['S1',41,1,1,3,23,0,1,41,0,14975,0,0]

# %%
data2.shape
# Out:
# (1002, 13)

# %%
data2.drop_duplicates(keep='last',inplace=True)

# %%
data2.head()
# Out:
#    ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 1  S2   37           0             0               0              5
# 2  S3   49           0             0               0             44
# 3  S4   24           0             0               0             40
# 4  S5   48           1             1               3             36
# 5  S6   48           1             0               0             50
#
#    Drinks_Tea  Lectures_Missed  Average_Assignments_Score  Exam_Result  \
# 1           1                8                         75            0
# 2           1                9                         52            0
# 3           1                1                         54            0
# 4           0                2                         32            0
# 5           0                4                         58            0
#
#    Age_in_days  hello  hi
# 1        13514      0   0
# 2        17897      0   0
# 3         8766      0   0
# ...

# %%
data2.reset_index().head()
# Out:
#    index  ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 0      1  S2   37           0             0               0              5
# 1      2  S3   49           0             0               0             44
# 2      3  S4   24           0             0               0             40
# 3      4  S5   48           1             1               3             36
# 4      5  S6   48           1             0               0             50
#
#    Drinks_Tea  Lectures_Missed  Average_Assignments_Score  Exam_Result  \
# 0           1                8                         75            0
# 1           1                9                         52            0
# 2           1                1                         54            0
# 3           0                2                         32            0
# 4           0                4                         58            0
#
#    Age_in_days  hello  hi
# 0        13514      0   0
# 1        17897      0   0
# ...

# %%
data2.set_index('ID',inplace=True)

# %%
data2.head()
# Out:
#     Age  Is_Married  Has_Children  Children_Count  Home_Distance  Drinks_Tea  \
# ID
# S2   37           0             0               0              5           1
# S3   49           0             0               0             44           1
# S4   24           0             0               0             40           1
# S5   48           1             1               3             36           0
# S6   48           1             0               0             50           0
#
#     Lectures_Missed  Average_Assignments_Score  Exam_Result  Age_in_days  \
# ID
# S2                8                         75            0        13514
# S3                9                         52            0        17897
# S4                1                         54            0         8766
# S5                2                         32            0        17532
# S6                4                         58            0        17532
#
#     hello  hi
# ID
# S2      0   0
# S3      0   0
# ...
