# %%
import pandas as pd

# %%
data=pd.DataFrame({'a':[1,2,3],
             'b':[7,8,9],
             'c':[12,13,14]},
                 index=[1,2,3])

# %%
data.head()
# Out:
#    a  b   c
# 1  1  7  12
# 2  2  8  13
# 3  3  9  14

# %%
data1=pd.DataFrame({'a':[1,2,3],
             'b':[7,8,9],
             'c':[12,13,14]})

# %%
data1.head()
# Out:
#    a  b   c
# 0  1  7  12
# 1  2  8  13
# 2  3  9  14

# %%
df1=pd.DataFrame(
    [[7,6,9],
     [15,78,69],
     [15,78,69]],

     index=[1,2,3],
     columns=['a','b','c'])

# %%
df1.head()
# Out:
#     a   b   c
# 1   7   6   9
# 2  15  78  69
# 3  15  78  69

# %%
df1.drop_duplicates()
# Out:
#     a   b   c
# 1   7   6   9
# 2  15  78  69

# %%
df1.head()
# Out:
#     a   b   c
# 1   7   6   9
# 2  15  78  69
# 3  15  78  69

# %%
df1["b"].drop_duplicates()
# Out:
# 1     6
# 2    78
# Name: b, dtype: int64

# %%
pd.melt(df1)
# Out:
#   variable  value
# 0        a      7
# 1        a     15
# 2        a     15
# 3        b      6
# 4        b     78
# 5        b     78
# 6        c      9
# 7        c     69
# 8        c     69

# %%
pd.concat([data,data1])
# Out:
#    a  b   c
# 1  1  7  12
# 2  2  8  13
# 3  3  9  14
# 0  1  7  12
# 1  2  8  13
# 2  3  9  14

# %%
pd.concat([data,data1],axis=1)
# Out:
#      a    b     c    a    b     c
# 0  NaN  NaN   NaN  1.0  7.0  12.0
# 1  1.0  7.0  12.0  2.0  8.0  13.0
# 2  2.0  8.0  13.0  3.0  9.0  14.0
# 3  3.0  9.0  14.0  NaN  NaN   NaN

# %%
pd.concat([data,data1],axis=0)
# Out:
#    a  b   c
# 1  1  7  12
# 2  2  8  13
# 3  3  9  14
# 0  1  7  12
# 1  2  8  13
# 2  3  9  14

# %%
import numpy as np

# crete a sample dataframe
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'B', 'B', 'A', 'A'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', np.NAN, 'yellow', np.NAN, 'black', 'green', 'red']
})

# view the data
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F             NaN
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M             NaN
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %%
data[data.age>15]
# Out:
#    age section    city gender favourite_color
# 1   22       B   Delhi      F             NaN
# 3   21       B   Delhi      M             NaN
# 6   17       A  Mumbai      F             red

# %%
data[data.age==17]=20

# %%
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F             NaN
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M             NaN
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   20      20       20     20              20

# %%
data.loc[(data.age==20),['section']]='M'

# %%
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F             NaN
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M             NaN
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   20       M       20     20              20

# %%
data.loc[(data.age>=20),['section','city']]=['M','Pune']

# %%
data.sort_values('age')
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 5   11       A    Delhi      M           green
# 4   12       B   Mumbai      M           black
# 2   13       C   Mumbai      F          yellow
# 6   20       M     Pune     20              20
# 3   21       M     Pune      M             NaN
# 1   22       M     Pune      F             NaN

# %%
for i in range(0,len(data)):
  if data['gender'][i]=='F':
    data['gender'][i]='M'
  else:
    data['gender'][i]='F'

# %%
for i in range(0,len(data)):
    if data.gender[i]=="M":
        data.gender[i]="f"
# Out:
# C:\Users\Sanchi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data.rename(columns={'city':'zila'})
# Out:
#    age section     zila gender favourite_color
# 0   10       A  Gurgaon      f             red
# 1   22       M     Pune      F             NaN
# 2   13       C   Mumbai      F          yellow
# 3   21       M     Pune      f             NaN
# 4   12       B   Mumbai      f           black
# 5   11       A    Delhi      f           green
# 6   20       M     Pune     20              20

# %%
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      f             red
# 1   22       M     Pune      F             NaN
# 2   13       C   Mumbai      F          yellow
# 3   21       M     Pune      f             NaN
# 4   12       B   Mumbai      f           black
# 5   11       A    Delhi      f           green
# 6   20       M     Pune     20              20

# %%
data.drop(columns="city")
# Out:
#    age section gender favourite_color
# 0   10       A      f             red
# 1   22       M      F             NaN
# 2   13       C      F          yellow
# 3   21       M      f             NaN
# 4   12       B      f           black
# 5   11       A      f           green
# 6   20       M     20              20

# %%
data.plot()

# %%
data.plot.hist()
