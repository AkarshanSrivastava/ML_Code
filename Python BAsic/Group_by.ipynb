# %%
import pandas as pd

# %%
data=pd.read_csv("demo1_historic.csv")

# %%
d=data.groupby('Age')

# %%
d

# %%
d.groups
# Out:
# {20: Int64Index([  6,  26,  41,  67, 128, 149, 165, 175, 190, 205, 206, 213, 240,
#              251, 253, 280, 291, 303, 321, 337, 346, 382, 473, 538, 578, 603,
#              684, 689, 717, 737, 746, 775, 852, 859, 906, 944, 947, 955, 979],
#             dtype='int64'),
#  21: Int64Index([ 13,  54,  60, 193, 207, 229, 256, 295, 409, 424, 460, 475, 490,
#              506, 546, 631, 635, 738, 777, 799, 810, 901, 948, 998],
#             dtype='int64'),
#  22: Int64Index([ 28,  44, 101, 109, 111, 130, 156, 189, 204, 226, 257, 259, 273,
#              307, 315, 330, 341, 397, 399, 402, 438, 466, 523, 531, 585, 589,
#              637, 759, 764, 791, 805, 822, 824, 828, 886, 889, 911, 916, 932,
#              933, 943, 946, 970],
#             dtype='int64'),
#  23: Int64Index([214, 275, 305, 318, 405, 415, 495, 504, 512, 542, 545, 553, 568,
#              582, 586, 600, 655, 743, 755, 774, 793, 800, 816, 842, 845, 881,
#              902, 980],
#             dtype='int64'),
# ...

# %%
d.get_group(21)
# Out:
#        ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 13    S14   21           0             0               0             41
# 54    S55   21           0             0               0             24
# 60    S61   21           0             0               0             46
# 193  S194   21           0             0               0             17
# 207  S208   21           0             0               0             37
# 229  S230   21           0             0               0             13
# 256  S257   21           1             0               0             35
# 295  S296   21           1             1               8             30
# 409  S410   21           1             0               0             48
# 424  S425   21           0             0               0             30
# 460  S461   21           1             1               2             26
# 475  S476   21           0             0               0             42
# ...

# %%
d.ngroups
# Out:
# 31

# %%
d.Age.nunique()
# Out:
# Age
# 20    1
# 21    1
# 22    1
# 23    1
# 24    1
# 25    1
# 26    1
# 27    1
# 28    1
# 29    1
# 30    1
# 31    1
# 32    1
# 33    1
# 34    1
# 35    1
# 36    1
# 37    1
# 38    1
# 39    1
# 40    1
# 41    1
# 42    1
# 43    1
# 44    1
# 45    1
# 46    1
# 47    1
# 48    1
# 49    1
# 50    1
# Name: Age, dtype: int64

# %%
d.groups.items()
# Out:
# dict_items([(20, Int64Index([  6,  26,  41,  67, 128, 149, 165, 175, 190, 205, 206, 213, 240,
#             251, 253, 280, 291, 303, 321, 337, 346, 382, 473, 538, 578, 603,
#             684, 689, 717, 737, 746, 775, 852, 859, 906, 944, 947, 955, 979],
#            dtype='int64')), (21, Int64Index([ 13,  54,  60, 193, 207, 229, 256, 295, 409, 424, 460, 475, 490,
#             506, 546, 631, 635, 738, 777, 799, 810, 901, 948, 998],
#            dtype='int64')), (22, Int64Index([ 28,  44, 101, 109, 111, 130, 156, 189, 204, 226, 257, 259, 273,
#             307, 315, 330, 341, 397, 399, 402, 438, 466, 523, 531, 585, 589,
#             637, 759, 764, 791, 805, 822, 824, 828, 886, 889, 911, 916, 932,
#             933, 943, 946, 970],
#            dtype='int64')), (23, Int64Index([214, 275, 305, 318, 405, 415, 495, 504, 512, 542, 545, 553, 568,
#             582, 586, 600, 655, 743, 755, 774, 793, 800, 816, 842, 845, 881,
#             902, 980],
# ...

# %%
for group_name, group_labels in d.groups.items():
    print('{} students are of age {}'.format(len(group_labels), group_name))
# Out:
# 39 students are of age 20
# 24 students are of age 21
# 43 students are of age 22
# 28 students are of age 23
# 37 students are of age 24
# 33 students are of age 25
# 32 students are of age 26
# 32 students are of age 27
# 34 students are of age 28
# 29 students are of age 29
# 20 students are of age 30
# 30 students are of age 31
# 30 students are of age 32
# 37 students are of age 33
# 30 students are of age 34
# 33 students are of age 35
# 30 students are of age 36
# 41 students are of age 37
# 27 students are of age 38
# 29 students are of age 39
# 41 students are of age 40
# 30 students are of age 41
# 44 students are of age 42
# 35 students are of age 43
# 29 students are of age 44
# 35 students are of age 45
# 24 students are of age 46
# 24 students are of age 47
# 31 students are of age 48
# 30 students are of age 49
# 39 students are of age 50
